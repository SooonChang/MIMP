# %% [markdown]
# # Colab & Git Init

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)

# %%
# %pwd

# %%
# %ls

# %%
# %cd drive/My\ Drive

# %%
# %ls

# %% [markdown]
# ## Git 설정
# * MY_GOOGLE_DRIVE_PATH
# * GIT_USERNAME
# * GIT_TOKEN (Github Access Token)
# * GIT_REPOSITORY

# %%
# path to your project on Google Dirve
MY_GOOGLE_DRIVE_PATH = 'My Drive'
# git user name
GIT_USERNAME = "SooonChang"
GIT_TOKEN = "0477f15e62f85bc93ec858100cf18bc827aa0f65"
GIT_REPOSITORY = "MIMP"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY
print(PROJECT_PATH)
print(GIT_PATH)

# %% [markdown]
# ## Git clone

# %%
# cd {PROJECT PATH}
# !git clone https://0477f15e62f85bc93ec858100cf18bc827aa0f65@github.com/SooonChang/MIMP

# %%
# %cd /content/drive/My\ Drive/MIMP

# %%
# !git status

# %%
# !git add colab_git_init.ipynb

# %%
# !git config --global user.email "sooonchang@gmail.com"
# !git config --global user.name "SooonChang"

# %%
# !git branch develop
# !git checkout develop

# %%
# !git branch
